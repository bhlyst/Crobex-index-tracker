# %%
## Importing packages ##

import requests
import pandas as pd
from pandas import json_normalize
import json
from datetime import date
from pathlib import Path

# %%
url = "https://zse.hr/json/IndexComposition?search=&sort=symbol&order=asc&isin=HRZB00ICBEX6&lng=hr"

resp = requests.get(url)
data = resp.json()

# %%
## Diagnostics to ensure the right key for extracting data#
#
# print(type(data))

# print(data.keys())
#
# print(json.dumps(data, indent = 2, ensure_ascii=False))

# %%
df = pd.DataFrame(data["rows"])

df["download_date"] = date.today().strftime("%Y-%m-%d")

print(df.head())
# Out:
#   lang  mic          isin                          name symbol  \
# 0   hr    0  HRADPLRA0006               AD PLASTIK d.d.   ADPL
# 1   hr    0  HRADRSPA0009              ADRIS GRUPA d.d.  ADRS2
# 2   hr    0  HRARNTRA0004  Arena Hospitality Group d.d.   ARNT
# 3   hr    0  HRATGRRA0003           ATLANTIC GRUPA d.d.   ATGR
# 4   hr    0  HRDDJHRA0007       DURO DAKOVIC GRUPA d.d.   DDJH
#
#   nominal_ammount nominal_currency_id_formatted        maturity_date  \
# 0               -                                0001-01-01T00:00:00
# 1               -                                0001-01-01T00:00:00
# 2               -                                0001-01-01T00:00:00
# 3               -                                0001-01-01T00:00:00
# 4               -                                0001-01-01T00:00:00
#
#   maturity_date_formatted interest_rate_percentage  ...  \
# 0             01.01.0001.                 -&nbsp;%  ...
# 1             01.01.0001.                 -&nbsp;%  ...
# 2             01.01.0001.                 -&nbsp;%  ...
# 3             01.01.0001.                 -&nbsp;%  ...
# 4             01.01.0001.                 -&nbsp;%  ...
#
#              last_trade_time last_trade_time_formatted  \
# 0  2025-10-03T18:00:14+02:00      03.10.2025. 18:00:14
# 1  2025-10-03T17:44:59+02:00      03.10.2025. 17:44:59
# 2  2025-10-03T17:43:57+02:00      03.10.2025. 17:43:57
# 3  2025-10-03T18:00:12+02:00      03.10.2025. 18:00:12
# 4  2025-10-01T15:41:32+02:00      01.10.2025. 15:41:32
#
#   last_trade_time_to_local_formatted weight_percentage       quantity  \
# 0               03.10.2025. 16:00:14       1,36&nbsp;%   4.199.584,00
# 1               03.10.2025. 15:44:59       9,72&nbsp;%   6.784.100,00
# 2               03.10.2025. 15:43:57       1,79&nbsp;%   5.128.721,00
# 3               03.10.2025. 16:00:12       6,96&nbsp;%  13.337.200,00
# 4               01.10.2025. 13:41:32       0,08&nbsp;%     101.532,00
#
#   change_prev_close_percentage free_float_factor weighting_factor  \
# 0                 +0,56&nbsp;%              0,70       1,00000000
# 1                 -1,00&nbsp;%              0,95       0,73725141
# 2                  0,00&nbsp;%              0,35       1,00000000
# 3                 +2,27&nbsp;%              0,45       1,00000000
# 4                            -              0,50       1,00000000
#
#   free_float_market_cap download_date
# 0         52.620.787,52    2025-10-05
# 1        377.269.729,33    2025-10-05
# 2         69.648.031,18    2025-10-05
# 3        270.078.300,00    2025-10-05
# 4          3.071.343,00    2025-10-05
#
# [5 rows x 21 columns]

# %%
file = Path("crobex_sastav_povijest.csv")

if file.exists() :
    old = pd.read_csv(file)
    combined = pd.concat([old, df], ignore_index = True)
    combined.to_csv(file, index = False, encoding = "utf-8")
else:
    df.to_csv(file, index = False, encoding = "utf-8")
